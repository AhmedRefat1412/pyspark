# %%
from kafka import KafkaProducer

# إنشاء Kafka Producer
producer = KafkaProducer(bootstrap_servers='localhost:9092')

# إرسال رسائل بسيطة لتوبيك اسمه test-topic
for i in range(5):
    message = f"Hello Kafka {i}".encode('utf-8') # لازم البيانات تتحول ل بايت عشان كاكفا بيخزن البيانات ك بيتا استريم 
    producer.send('test-topic', message) 

producer.flush() # استنا لحد كل الرسائل الي في البافر اتبعتت ل البروكر 
print("✅ Messages sent successfully!")
# Out:
# ✅ Messages sent successfully!

# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'test-topic',  #   topic دا اسم ال 
    bootstrap_servers='localhost:9092',# ده عنوان الـ Kafka Broker
    auto_offset_reset='earliest', #يبدأ من أول رسالة موجودة في التوبيك (البداية). 
    # latest يبدء من اخر رساله اتبعت ويتجاهل القديم  
    enable_auto_commit=True, # معناها إن الكونسومر هيخزن أوتوماتيك مكان آخر رسالة قراها عشان لما يفتح تاني، يكمل من بعدها.
    group_id='test-group'
)

print("📥 Waiting for messages...\n")

for message in consumer:
    print(f"Received: {message.value.decode('utf-8')}")  # لازم نحول الرساله من كافكا عشان تتحول لنص عشان هي جايه علي هئيه بايت
# Out:
# 📥 Waiting for messages...
#
# Received: Hello Kafka 0
# Received: Hello Kafka 1
# Received: Hello Kafka 2
# Received: Hello Kafka 3
# Received: Hello Kafka 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#       3 consumer = KafkaConsumer(
#       4     'test-topic',
#       5     bootstrap_servers='localhost:9092',
#    (...)
#       8     group_id='test-group'
#       9 )
#      11 print("📥 Waiting for messages...\n")
# ---> 13 for message in consumer:
#      14     print(f"Received: {message.value.decode('utf-8')}")
#
# File ~/miniconda3/envs/pyspark_env/lib/python3.10/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# ...
